# %%
# Rayleigh Distribution

# The Rayleigh distribution is often used to model the magnitude of a two-dimensional vector  
# whose components are independent and normally distributed.

# It has two key parameters:
# - `scale`: controls the spread (width) of the distribution  
# - `size`: number of random values to generate

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate 1000 samples from a Rayleigh distribution with scale = 2
data = np.random.rayleigh(scale=2.0, size=1000)

# Plot with seaborn
sns.histplot(data, bins=30, kde=True, color="steelblue", edgecolor="black")

plt.title("Rayleigh Distribution (scale = 2.0)")
plt.xlabel("Value")
plt.ylabel("Density")

plt.show()

#Generates 1000 values from a Rayleigh distribution  
#with a scale parameter of 2.0.

# - `scale`: controls the spread (width) of the distribution  
# - `size`: number of random values to generate
