# %%
# Poisson Distribution

# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space.

# It is defined by a single parameter:
# - `λ` (lambda): the expected number of occurrences within the interval

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Generate 1000 samples from a Poisson distribution with λ=5
# lam=5 → expected number of events
# size=1000 → how many values to generate

data = np.random.poisson(lam=5, size=1000)

# Plot with seaborn
sns.histplot(data)

plt.title("Poisson Distribution (λ = 5)")
plt.xlabel("Number of Events")
plt.ylabel("Frequency")

plt.show()
